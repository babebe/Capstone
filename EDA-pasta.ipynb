# %%
import pandas as pd

# %%
df=pd.read_csv('pasta_main.csv')
df=pd.read_csv('pasta_flavors.csv')
df=pd.read_csv('pasta_ingredients.csv')
df=pd.read_csv('pasta_attributes.csv')

# %%
df.shape
# Out:
# (1000, 1225)

# %%
df
# Out:
#      Unnamed: 0  4th of July  American  Appetizers  Asian  Barbecue  \
# 0             0          NaN       NaN         NaN    NaN       NaN
# 1             1          NaN       NaN         NaN    NaN       NaN
# 2             2          NaN       NaN         NaN    NaN       NaN
# 3             3          NaN       NaN         NaN    NaN       NaN
# 4             4          NaN       NaN         NaN    NaN       NaN
# 5             5          NaN       NaN         NaN    NaN       NaN
# 6             6          NaN       NaN         NaN    NaN       NaN
# 7             7          NaN       NaN         NaN    NaN       NaN
# 8             8          NaN       NaN         NaN    NaN       NaN
# 9             9          NaN       NaN         NaN    NaN       NaN
# 10           10          NaN       NaN         NaN    NaN       NaN
# 11           11          NaN       NaN         NaN    NaN       NaN
# 12           12          NaN       NaN         NaN    NaN       NaN
# ...
